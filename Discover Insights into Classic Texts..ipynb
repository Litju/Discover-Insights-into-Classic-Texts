# %%
import nltk
from nltk import pos_tag, RegexpParser
from nltk.tokenize import word_tokenize, sent_tokenize
from collections import Counter

# Custom functions
def word_sentence_tokenize(text):
    sentences = sent_tokenize(text)
    word_tokenized_sentences = [word_tokenize(sentence) for sentence in sentences]
    return word_tokenized_sentences

def np_chunk_counter(chunked_text):
    np_chunks = []
    for tree in chunked_text:
        for subtree in tree.subtrees(filter=lambda t: t.label() == 'NP'):
            np_chunks.append(' '.join(word for word, tag in subtree.leaves()))
    return Counter(np_chunks).most_common()

def vp_chunk_counter(chunked_text):
    vp_chunks = []
    for tree in chunked_text:
        for subtree in tree.subtrees(filter=lambda t: t.label() == 'VP'):
            vp_chunks.append(' '.join(word for word, tag in subtree.leaves()))
    return Counter(vp_chunks).most_common()

# Import text data
file_name = "dorian_gray.txt"  # Change to "the_iliad.txt" for The Iliad
text = open(file_name, encoding='utf-8').read().lower()

# Tokenize sentences and words
word_tokenized_text = word_sentence_tokenize(text)

# Print a single word tokenized sentence
single_word_tokenized_sentence = word_tokenized_text[100]
print("Single Word Tokenized Sentence:", single_word_tokenized_sentence)

# Part-of-speech tagging
pos_tagged_text = [pos_tag(sentence) for sentence in word_tokenized_text]

# Print a single part-of-speech tagged sentence
single_pos_sentence = pos_tagged_text[100]
print("Single POS Tagged Sentence:", single_pos_sentence)

# Define chunk grammars
np_chunk_grammar = """
    NP: {<DT>?<JJ>*<NN>}
"""
vp_chunk_grammar = """
    VP: {<VB.*><NP|PP|CLAUSE>*}
"""

# Create chunk parsers
np_chunk_parser = RegexpParser(np_chunk_grammar)
vp_chunk_parser = RegexpParser(vp_chunk_grammar)

# Chunk sentences
np_chunked_text = [np_chunk_parser.parse(sentence) for sentence in pos_tagged_text]
vp_chunked_text = [vp_chunk_parser.parse(sentence) for sentence in pos_tagged_text]

# Analyze and print most common NP and VP chunks
most_common_np_chunks = np_chunk_counter(np_chunked_text)
print("Most Common NP Chunks:", most_common_np_chunks)

most_common_vp_chunks = vp_chunk_counter(vp_chunked_text)
print("Most Common VP Chunks:", most_common_vp_chunks)
# Out:
# Single Word Tokenized Sentence: ['it', 'seems', 'to', 'be', 'the', 'one', 'thing', 'that', 'can', 'make', 'modern', 'life', 'mysterious', 'or', 'marvellous', 'to', 'us', '.']
# Single POS Tagged Sentence: [('it', 'PRP'), ('seems', 'VBZ'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('one', 'CD'), ('thing', 'NN'), ('that', 'WDT'), ('can', 'MD'), ('make', 'VB'), ('modern', 'JJ'), ('life', 'NN'), ('mysterious', 'JJ'), ('or', 'CC'), ('marvellous', 'JJ'), ('to', 'TO'), ('us', 'PRP'), ('.', '.')]
# Most Common NP Chunks: [('i', 962), ('henry', 200), ('lord', 197), ('life', 170), ('harry', 136), ('dorian gray', 127), ('something', 126), ('nothing', 93), ('basil', 85), ('the world', 70), ('everything', 69), ('anything', 68), ('hallward', 68), ('the man', 61), ('the room', 60), ('face', 57), ('the door', 56), ('love', 55), ('art', 52), ('course', 51), ('the picture', 46), ('the lad', 45), ('head', 44), ('round', 44), ('hand', 44), ('sibyl', 41), ('the table', 40), ('the painter', 38), ('sir', 38), ('a moment', 38), ('time', 37), ('dorian', 37), ('mother', 36), ('beauty', 35), ('ah', 35), ('a man', 33), ('man', 30), ('name', 30), ('soul', 30), ('the duchess', 29), ('alan', 29), ('the thing', 28), ('pain', 28), ('the portrait', 28), ('vane', 27), ('death', 26), ('gray', 25), ('youth', 25), ('pleasure', 24), ('lord henry', 24), ('home', 24), ('sibyl vane', 24), ('campbell', 24), ('the face', 23), ('the house', 23), ('chapter', 22), ('front', 22), ('god', 21), ('some day', 20), ('gold', 20), ('sin', 20), ('the girl', 20), ('night', 20), ('wife', 19), ('terror', 19), ('mind', 19), ('music', 19), ('passion', 19), ('work', 18), ('the soul', 18), ('the canvas', 18), ('no one', 18), ('voice', 18), ('horror', 18), ('thing', 17), ('nature', 17), ('mr.', 17), ('money', 17), ('the window', 17), ('the garden', 16), ('the time', 16), ('dear fellow', 16), ('coat', 16), ('day', 16), ('good-bye', 16), ('joy', 16), ('way', 15), ('england', 15), ('heart', 15), ('colour', 15), ('silver', 15), ('the air', 15), ('the club', 15), ('charming', 15), ('a woman', 15), ('prince', 15), ('the screen', 15), ('the key', 15), ('one', 14), ('friend', 14), ('servant', 14), ('hair', 14), ('a look', 14), ('any rate', 14), ('an hour', 14), ('the theatre', 14), ('dinner', 14), ('blood', 14), ('jim', 14), ('thought', 13), ('london', 13), ('the way', 13), ('mr. gray', 13), ('the brain', 13), ('shame', 13), ('age', 13), ('father', 13), ('paris', 13), ('chair', 13), ('the artist', 12), ('fact', 12), ('basil hallward', 12), ('store', 12), ('body', 12), ('aunt', 12), ("o'clock", 12), ('uncle', 12), ('valet', 12), ('son', 12), ('the whole thing', 12), ('yesterday', 12), ('house', 12), ('the opera', 12), ('brain', 11), ('romance', 11), ('marriage', 11), ('some time', 11), ('the secret', 11), ('own soul', 11), ('mine', 11), ('a cigarette', 11), ('lip', 11), ('this morning', 11), ('duchess', 11), ('interest', 11), ('view', 10), ('word', 10), ('dear basil', 10), ('the moment', 10), ('picture', 10), ('the play', 10), ('town', 10), ('society', 10), ('conscience', 10), ('the young man', 10), ('everybody', 10), ('hat', 10), ('the passion', 10), ('place', 10), ('i wish', 10), ('forehead', 10), ('no answer', 10), ('a gentleman', 10), ('george', 10), ('that kind', 10), ('the park', 10), ('dear boy', 10), ('sister', 10), ('a sigh', 10), ('lady narborough', 10), ('form', 9), ('part', 9), ('the studio', 9), ('the corner', 9), ('wotton', 9), ('look', 9), ('the reason', 9), ('till', 9), ('a sort', 9), ('brother', 9), ('the idea', 9), ('no doubt', 9), ('cheeks', 9), ('self', 9), ('the hand', 9), ('boyhood', 9), ('a book', 9), ('the bell', 9), ('the memory', 9), ('arm', 9), ('wonder', 9), ('the stage', 9), ('i assure', 9), ('husband', 9), ('the matter', 9), ('the past', 9), ('the floor', 9), ('cruelty', 9), ('a boy', 8), ('history', 8), ('afraid i', 8), ('the wall', 8), ('anybody', 8), ('the first time', 8), ('mr', 8), ('personality', 8), ('portrait', 8), ('lady agatha', 8), ('flung', 8), ('reality', 8), ('the body', 8), ('fire', 8), ('fear', 8), ('the life', 8), ('....', 8), ('trouble', 8), ('studio', 8), ('heard', 8), ('matter', 8), ('the curtain', 8), ('a thing', 8), ('the hall', 8), ('secret', 8), ('the top', 8), ('eye', 8), ('the library', 8), ('sorry', 8), ('adrian singleton', 8), ('the nineteenth century', 7), ('the work', 7), ('summer', 7), ('charm', 7), ('the sunlight', 7), ('a pause', 7), ('watch', 7), ('the ground', 7), ('ear', 7), ('the piano', 7), ('a friend', 7), ('none', 7 ...
# Most Common VP Chunks: [('was', 1090), ('is', 915), ('had', 837), ('have', 560), ('be', 453), ('do', 428), ('are', 373), ('said', 262), ('were', 251), ('been', 236), ('am', 232), ('i', 186), ('know', 175), ('has', 171), ('think', 124), ('see', 121), ('did', 120), ('seemed', 119), ('come', 116), ('go', 115), ('made', 108), ('want', 103), ('came', 99), ('say', 96), ('looked', 94), ('tell', 92), ('going', 87), ('cried', 87), ('answered', 86), ('told', 77), ('felt', 76), ('let', 66), ('being', 63), ('went', 63), ('asked', 61), ('make', 60), ('passed', 60), ('looking', 58), ('thought', 58), ('look', 57), ('turned', 54), ('got', 54), ('done', 50), ('left', 49), ('believe', 48), ('love', 47), ('knew', 46), ('found', 46), ('does', 45), ('get', 45), ('began', 44), ('murmured', 42), ('take', 42), ('put', 41), ('laughed', 41), ('saw', 41), ('seen', 41), ('talk', 40), ('met', 40), ('like', 39), ('give', 38), ('used', 37), ('having', 36), ('feel', 34), ('took', 34), ('find', 33), ('stood', 33), ('forget', 33), ('suppose', 32), ('became', 30), ('ask', 30), ('read', 29), ('sat', 29), ('opened', 29), ('seems', 28), ('heard', 28), ('makes', 27), ('brought', 27), ('help', 27), ('become', 27), ('mean', 26), ('gone', 26), ('known', 26), ('entered', 26), ('wish', 26), ('understand', 25), ('live', 25), ('call', 25), ('harry', 25), ('try', 25), ('sit', 24), ('shook', 24), ('remember', 24), ('walked', 24), ('painted', 23), ('drew', 23), ('rose', 23), ('gave', 22), ('exclaimed', 22), ('called', 22), ('basil', 21), ('leave', 21), ('remembered', 21), ('happened', 21), ('loved', 21), ('charming', 20), ('given', 20), ('married', 20), ('hear', 20), ('grew', 20), ('spoke', 20), ('watched', 20), ('died', 20), ('changed', 20), ('filled', 19), ('set', 19), ('laughing', 19), ('glanced', 19), ('keep', 19), ('fell', 19), ('broke', 19), ('lying', 18), ('started', 18), ('doing', 18), ('coming', 18), ('says', 18), ('kept', 18), ('waiting', 18), ('stirred', 17), ('bear', 17), ('bring', 17), ('smiled', 17), ('talking', 17), ('wonder', 17), ('speak', 17), ('lost', 17), ('smiling', 17), ('taking', 17), ('taken', 17), ('wanted', 17), ('muttered', 17), ('fancy', 17), ('send', 16), ('killed', 16), ('followed', 16), ('play', 16), ('sitting', 15), ('saying', 15), ('played', 15), ('stay', 15), ('touched', 15), ('stopped', 15), ('sent', 15), ('marry', 15), ('hope', 15), ('round', 14), ('sought', 14), ('telling', 14), ('meet', 14), ('care', 14), ('tired', 14), ('appeared', 14), ('write', 14), ('reached', 14), ('moved', 13), ('die', 13), ('taught', 13), ('kill', 13), ('sighed', 13), ('making', 12), ('seem', 12), ('lose', 12), ('knows', 12), ('revealed', 12), ('wondered', 12), ('trying', 12), ('alter', 12), ('discovered', 12), ('whispered', 12), ('hung', 12), ('placed', 11), ('walking', 11), ('shown', 11), ('continued', 11), ('show', 11), ('giving', 11), ('comes', 11), ('caught', 11), ('standing', 11), ('listen', 11), ('pay', 11), ('forgotten', 11), ('finished', 11), ('laid', 11), ('lived', 11), ('putting', 11), ('determined', 11), ('ran', 11), ('written', 10), ('exhibit', 10), ('dare', 10), ('dine', 10), ('faces', 10), ('led', 10), ('gazing', 10), ('covered', 10), ('hidden', 10), ('realize', 10), ('change', 10), ('struck', 10), ('spoiled', 10), ('hesitated', 10), ('frowned', 10), ('altered', 10), ('flung', 10), ('hated', 10), ('lay', 10), ('crept', 10), ('waited', 10), ('watch', 10), ('kissed', 10), ('acting', 10), ('threw', 10), ('leaning', 9), ('allowed', 9), ('escape', 9), ('turning', 9), ('promised', 9), ('worshipped', 9), ("'s", 9), ('troubled', 9), ('passing', 9), ('charmed', 9), ('shrugged', 9), ('watching', 9), ('playing', 9), ('shaking', 9), ('thinking', 9), ('annoyed', 9), ('drove', 9), ('stir', 9), ('ceased', 9), ('showed', 9), ('act', 9), ('rushed', 9), ('dressed', 9), ('marred', 9), ('held', 9), ('embroidered', 9), ('forgive', 8), ('stretched', 8), ('hate', 8), ('examined', 8), ('wants', 8), ('tried', 8), ('afraid', 8), ('paint', 8), ('missed', 8), ('seated', 8), (' ...
